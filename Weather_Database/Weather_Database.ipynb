# %%
from citipy import citipy
import pandas as pd
import numpy as np
import random
import requests
from datetime import datetime
import gmaps

from key import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2000 latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
ex_data = city_weather.json()
ex_data
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 56.19,
#   'feels_like': 54.95,
#   'temp_min': 55,
#   'temp_max': 57,
#   'pressure': 1026,
#   'humidity': 95},
#  'visibility': 10000,
#  'wind': {'speed': 4.83, 'deg': 108},
#  'clouds': {'all': 13},
#  'dt': 1603422519,
#  'sys': {'type': 3,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1603364744,
#   'sunset': 1603403473},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
a_data = ex_data["weather"]

b_data = a_data[0]["description"]
b_data
# Out:
# 'few clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        describe_weather = city_weather["weather"]
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = describe_weather[0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | mabaruma
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 10 of Set 1 | tasiilaq
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | turochak
# Processing Record 13 of Set 1 | malanje
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | yar-sale
# Processing Record 18 of Set 1 | jacksonville
# ...

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#              City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Vardo  70.37  31.11     35.60        95          75       26.40
# 1       Cape Town -33.93  18.42     62.01        93          75        6.93
# 2    Ponta Do Sol  32.67 -17.10     64.40        68          40       13.87
# 3        Mabaruma   8.20 -59.78     78.87        82          58        6.13
# 4        Hermanus -34.42  19.23     63.00        85          63        2.44
# ..            ...    ...    ...       ...       ...         ...         ...
# 696      Teguldet  57.31  88.17     36.54        80          25        9.15
# 697    Perivolion  39.42  20.01     59.00        93           0        4.56
# 698        Alvand  36.32  49.17     47.66        61           0        2.24
# 699         Werda -25.27  23.28     72.61        38           0       10.09
# 700        Dubova  44.62  22.27     51.62        48           0        2.91
#
#     Country Current Description
# ...

# %%
new_headers = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_headers]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vardo      NO  70.37   31.11     35.60        95          75
# 1     Cape Town      ZA -33.93   18.42     62.01        93          75
# 2  Ponta Do Sol      PT  32.67  -17.10     64.40        68          40
# 3      Mabaruma      GY   8.20  -59.78     78.87        82          58
# 4      Hermanus      ZA -34.42   19.23     63.00        85          63
# 5     Grindavik      IS  63.84  -22.43     41.00        80          90
# 6      Tasiilaq      GL  65.61  -37.64     37.40        47         100
# 7     Busselton      AU -33.65  115.33     73.00        34           0
# 8      Turochak      RU  52.26   87.12     38.86        87         100
# 9       Malanje      AO  -9.54   16.34     64.31        97          93
#
#    Wind Speed Current Description
# 0       26.40       broken clouds
# 1        6.93       broken clouds
# 2       13.87    scattered clouds
# 3        6.13       broken clouds
# ...

# %%
# Create output CSV file
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe into a CSV
city_data_df.to_csv(output_data_file, index="City_ID")
